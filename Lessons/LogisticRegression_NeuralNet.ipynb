# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu"))

# Make sure variables are arrays and not lists
X_train_scaled = np.asarray(X_train_scaled)
y_train = np.asarray(y_train)

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/50
# 576/576 [==============================] - 2s 3ms/sample - loss: 3.7335 - accuracy: 0.5069
# Epoch 2/50
# 576/576 [==============================] - 0s 155us/sample - loss: 3.4935 - accuracy: 0.5382
# Epoch 3/50
# 576/576 [==============================] - 0s 176us/sample - loss: 3.4207 - accuracy: 0.5660
# Epoch 4/50
# 576/576 [==============================] - 0s 146us/sample - loss: 3.2901 - accuracy: 0.5816
# Epoch 5/50
# 576/576 [==============================] - 0s 222us/sample - loss: 3.1681 - accuracy: 0.5729
# Epoch 6/50
# 576/576 [==============================] - 0s 138us/sample - loss: 3.0706 - accuracy: 0.5642
# Epoch 7/50
# 576/576 [==============================] - 0s 149us/sample - loss: 3.0537 - accuracy: 0.5677
# Epoch 8/50
# 576/576 [==============================] - 0s 138us/sample - loss: 2.9981 - accuracy: 0.5694
# Epoch 9/50
# 576/576 [==============================] - 0s 215us/sample - loss: 2.9635 - accuracy: 0.5747
# Epoch 10/50
# 576/576 [==============================] - 0s 162us/sample - loss: 2.8897 - accuracy: 0.5799
# Epoch 11/50
# 576/576 [==============================] - 0s 211us/sample - loss: 2.8466 - accuracy: 0.5903
# Epoch 12/50
# 576/576 [==============================] - 0s 160us/sample - loss: 2.7947 - accuracy: 0.5955
# Epoch 13/50
# 576/576 [==============================] - 0s 133us/sample - loss: 2.7217 - accuracy: 0.5938
# Epoch 14/50
# 576/576 [==============================] - 0s 130us/sample - loss: 2.6427 - accuracy: 0.6024
# Epoch 15/50
# 576/576 [==============================] - 0s 145us/sample - loss: 2.5099 - accuracy: 0.6128
# Epoch 16/50
# 576/576 [==============================] - 0s 180us/sample - loss: 2.4406 - accuracy: 0.6250
# Epoch 17/50
# 576/576 [==============================] - 0s 125us/sample - loss: 2.3129 - accuracy: 0.6406
# Epoch 18/50
# 576/576 [==============================] - 0s 149us/sample - loss: 2.0883 - accuracy: 0.6354
# Epoch 19/50
# 576/576 [==============================] - 0s 123us/sample - loss: 1.8804 - accuracy: 0.6319
# Epoch 20/50
# 576/576 [==============================] - 0s 136us/sample - loss: 1.8186 - accuracy: 0.6406
# Epoch 21/50
# 576/576 [==============================] - 0s 129us/sample - loss: 1.7791 - accuracy: 0.6441
# Epoch 22/50
# 576/576 [==============================] - 0s 170us/sample - loss: 1.6881 - accuracy: 0.6528
# Epoch 23/50
# 576/576 [==============================] - 0s 151us/sample - loss: 1.6072 - accuracy: 0.6476
# Epoch 24/50
# 576/576 [==============================] - 0s 205us/sample - loss: 1.5872 - accuracy: 0.6476
# Epoch 25/50
# 576/576 [==============================] - 0s 135us/sample - loss: 1.5716 - accuracy: 0.6510
# Epoch 26/50
# 576/576 [==============================] - 0s 145us/sample - loss: 1.5054 - accuracy: 0.6562
# Epoch 27/50
# 576/576 [==============================] - 0s 171us/sample - loss: 1.4200 - accuracy: 0.6615
# Epoch 28/50
# 576/576 [==============================] - 0s 143us/sample - loss: 1.2796 - accuracy: 0.6736
# Epoch 29/50
# 576/576 [==============================] - 0s 171us/sample - loss: 1.2127 - accuracy: 0.6736
# Epoch 30/50
# 576/576 [==============================] - 0s 190us/sample - loss: 1.1585 - accuracy: 0.6736
# Epoch 31/50
# 576/576 [==============================] - 0s 138us/sample - loss: 1.1203 - accuracy: 0.6823
# Epoch 32/50
# 576/576 [==============================] - 0s 181us/sample - loss: 1.0886 - accuracy: 0.6806
# Epoch 33/50
# 576/576 [==============================] - 0s 142us/sample - loss: 1.0580 - accuracy: 0.6823
# Epoch 34/50
# 576/576 [==============================] - 0s 152us/sample - loss: 1.0468 - accuracy: 0.6858
# Epoch 35/50
# 576/576 [==============================] - 0s 126us/sample - loss: 1.0027 - accuracy: 0.6910
# Epoch 36/50
# 576/576 [==============================] - 0s 145us/sample - loss: 0.9909 - accuracy: 0.6858
# Epoch 37/50
# 576/576 [==============================] - 0s 149us/sample - loss: 0.9656 - accuracy: 0.6892
# Epoch 38/50
# 576/576 [==============================] - 0s 185us/sample - loss: 0.8971 - accuracy: 0.7014
# Epoch 39/50
# 576/576 [==============================] - 0s 158us/sample - loss: 0.8493 - accuracy: 0.7031
# Epoch 40/50
# 576/576 [==============================] - 0s 209us/sample - loss: 0.8211 - accuracy: 0.7049
# Epoch 41/50
# 576/576 [==============================] - 0s 183us/sample - loss: 0.8115 - accuracy: 0.7066
# Epoch 42/50
# 576/576 [==============================] - ETA: 0s - loss: 0.8372 - accuracy: 0.71 - 0s 173us/sample - loss: 0.7844 - accuracy: 0.7083
# Epoch 43/50
# 576/576 [==============================] - 0s 319us/sample - loss: 0.7770 - accuracy: 0.7101
# Epoch 44/50
# 576/576 [==============================] - 0s 189us/sample - loss: 0.7549 - accuracy: 0.7153
# Epoch 45/50
# 576/576 [==============================] - 0s 177us/sample - loss: 0.7472 - accuracy: 0.7170
# Epoch 46/50
# 576/576 [==============================] - 0s 207us/sample - loss: 0.7419 - accuracy: 0.7205
# Epoch 47/50
# 576/576 [==============================] - 0s 187us/sample - loss: 0.7379 - accuracy: 0.7222
# Epoch 48/50
# 576/576 [==============================] - 0s 638us/sample - loss: 0.7342 - accuracy: 0.7222
# Epoch 49/50
# 576/576 [==============================] - 0s 233us/sample - loss: 0.7313 - accuracy: 0.7240
# Epoch 50/50
# 576/576 [==============================] - 0s 200us/sample - loss: 0.7276 - accuracy: 0.7274
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-004179c28756> in <module>
#      15
#      16 # Evaluate the model using the test data
# ---> 17 model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
#      18 print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     831         max_queue_size=max_queue_size,
#     832         workers=workers,
# --> 833         use_multiprocessing=use_multiprocessing)
#     834
#     835   def predict(self,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in evaluate(self, model, x, y, batch_size, verbose, sample_weight, steps, callbacks, **kwargs)
#     454     return self._model_iteration(
#     455         model, ModeKeys.TEST, x=x, y=y, batch_size=batch_size, verbose=verbose,
# --> 456         sample_weight=sample_weight, steps=steps, callbacks=callbacks, **kwargs)
#     457
#     458   def predict(self, model, x, batch_size=None, verbose=0, steps=None,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, **kwargs)
#     394           sample_weights=sample_weight,
#     395           steps=steps,
# --> 396           distribution_strategy=strategy)
#     397       total_samples = _get_total_number_of_samples(adapter)
#     398       use_sample = total_samples is not None
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     583                     use_multiprocessing=False):
#     584   """Process the inputs for fit/eval/predict()."""
# --> 585   adapter_cls = data_adapter.select_data_adapter(x, y)
#     586   if adapter_cls in _ADAPTER_FOR_STANDARDIZE_USER_DATA:
#     587     x, y, sample_weights = model._standardize_user_data(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/data_adapter.py in select_data_adapter(x, y)
#     651         "Failed to find data adapter that can handle "
#     652         "input: {}, {}".format(
# --> 653             _type_name(x), _type_name(y)))
#     654   elif len(adapter_cls) > 1:
#     655     raise RuntimeError(
#
# ValueError: Failed to find data adapter that can handle input: <class 'numpy.ndarray'>, <class 'pandas.core.series.Series'>
